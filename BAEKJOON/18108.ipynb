# %% [markdown]
# <a href="https://colab.research.google.com/github/ddah0329/Self-Study/blob/main/BAEKJOON/Python/18108.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![스크린샷 2024-02-21 오후 5.25.08.png](data:image/png;base64,...)
#
# > [백준 18108번](https://www.acmicpc.net/problem/18108)

# %%
Buddhist_Yr = int(input("불기 연도: "))
AD_Yr = Buddhist_Yr - 543
print(AD_Yr)
# Out:
# 불기 연도: 2541
# 1998

# %%
Buddhist_Yr = int(input("불기 연도: "))
print(Buddhist_Yr - 543)
# Out:
# 불기 연도: 2541
# 1998

# %%
print(int(input("불기 연도: ")) - 543)
# Out:
# 불기 연도: 2541
# 1998

# %% [markdown]
# # ⬇️ 최종 답안

# %%
print(int(input()) - 543)
# Out:
# 2541
# 1998

# %% [markdown]
# input()안에 출력형태의 어느것도 작성하면 안됨!
