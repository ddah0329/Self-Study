# %% [markdown]
# <a href="https://colab.research.google.com/github/ddah0329/Self-Study/blob/main/BAEKJOON/Python/10171~2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #고양이, 개 만들기
#
# ### - 문제
# 아래 예제와 같이 고양이/개를 출력하시오.
#
# ### - 입력
# 없음.
#
# ### - 출력
# 고양이/개를 출력한다.
#
# ### - 예제
# ![고양이.png](data:image/png;base64,...)![개.png](data:image/png;base64,...)
#
# <br>
#
# > [백준 10171번](https://www.acmicpc.net/problem/10171)
#
#
# > [백준 10172번](https://www.acmicpc.net/problem/10172)

# %% [markdown]
# # ⬇️ 최종 답안

# %%
print("\\    /\\")
print(" )  ( ')")
print("(  /  )")
print(" \(__)|")
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|

# %% [markdown]
# 역슬래시는 2개 써야 한개로 인식된다!!

# %%
print('|\\_/|')
print('|q p|   /}')
print('( 0 )"""\\')
print('|"^"`    |')
print('||_/=\\\\__|')
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|
